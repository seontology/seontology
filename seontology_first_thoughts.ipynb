# %% [raw]
# ---
# format:
#   html:
#     theme: cosmo
#     embed-resources: true
#     code-fold: true
#     grid:
#         body-width:	1000px
# toc: true
# ---

# %% [markdown]
# <a href="https://github.com/seontology/seontology"><img src="https://github.com/seontology/seontology/blob/main/.assets/seontology_logo.png?raw=true"></img></a>
#
#
# # Representing a web page as a `WebPage` class
#
# Initial workflow to create a representation of the `WebPage` class developed as part of **SEOntology** by [WordLift](https://wordlift.io/). This notebook covers Phase 1, as outlined below:
#
# ## Phase 1: Extracting standard elements that exist on almost any web page
#
# * Example elements: title tag, meta description, images, links, etc.
# * Crawl a set of URLs or a full website
# * Extract the required elements from each page
# * Create a JSON representation according to [SEOntology](https://github.com/seontology/seontology)
#
# ## Phase 2: Extracting certain elements that may exist on a web page in various formats
# * Examples: Author information, publishing date, last update, etc.
# * This phase requires custom crawling to extract this information.
# * In some cases this can be provided in an easily-parseable format like JSON-LD, which can be automated.
# * In some cases custom extraction using XPath/CSS selectors might be required.
#
# ## Phase 3: Adding website data, which can be automated but requires access to the data
# * Sources: Google Search Console, Google Analytics, etc.
# * Special scripts can be written to standardize the process of extracting this information from the relevant API

# %%
import advertools as adv
import pandas as pd
pd.options.display.max_columns = None
pd.set_option('future.no_silent_downcasting', True)

# %% [markdown]
# ## Get website URLs from XML sitemap and crawl the website

# %%
# wl = adv.sitemap_to_df('https://wordlift.io/sitemap.xml')
# adv.crawl(wl['loc'].dropna(), 'wordlift_crawl.jl')
crawl_df = pd.read_json('wordlift_crawl.jl', lines=True)
crawl_df.head(3)
# Out:
#                                                  url  \
# 0  https://wordlift.io/academy-entries/knowledge-...
# 1  https://wordlift.io/academy-entries/mobile-fir...
# 2  https://wordlift.io/academy-entries/dati-strut...
#
#                                                title  \
# 0  Knowledge Graph and Panels | Webinar With Andr...
# 1    Mobile First Indexing | Webinar with Cindy Krum
# 2  Come sfruttare i dati strutturati per aumentar...
#
#                                            meta_desc  \
# 0  Join the webinar to learn all the relevant tip...
# 1  If you are working in SEO, you really can’t ig...
# 2  Scopri come aumentare esposizione e visibilità...
#
#                                             viewport charset  \
# 0  width=device-width, initial-scale=1.0, maximum...   UTF-8
# 1  width=device-width, initial-scale=1.0, maximum...   UTF-8
# 2  width=device-width, initial-scale=1.0, maximum...   UTF-8
#
#                                                   h1  \
# 0  Knowledge Graph and Panels | Webinar With Andr...
# 1    Mobile First Indexing | Webinar with Cindy Krum
# 2  Come sfruttare i dati strutturati per aumentar...
#
#                                                   h3  \
# 0  Are you ready for the next SEO? Try WordLift t...
# 1  Are you ready for the next SEO? Try WordLift t...
# 2  Are you ready for the next SEO? Try WordLift t...
#
#                                      h4  \
# 0  Company@@Plans@@Learn@@Helpful Links
# 1  Company@@Plans@@Learn@@Helpful Links
# 2  Company@@Plans@@Learn@@Helpful Links
#
#                                            canonical  \
# 0  https://wordlift.io/academy-entries/knowledge-...
# 1  https://wordlift.io/webinar-mobile-first-index...
# 2  https://wordlift.io/it/academy-entries/dati-st...
#
#                                             alt_href og:locale  og:type  \
# 0  https://wordlift.io/feed/@@https://wordlift.io...     en_US  article
# 1  https://wordlift.io/feed/@@https://wordlift.io...     en_US  article
# 2  https://wordlift.io/feed/@@https://wordlift.io...     en_US  article
#
#                                             og:title  \
# 0  Knowledge Graph and Panels | Webinar With Andr...
# 1    Mobile First Indexing | Webinar with Cindy Krum
# 2  Come sfruttare i dati strutturati per aumentar...
#
#                                       og:description  \
# 0  Join the webinar to learn all the relevant tip...
# 1  If you are working in SEO, you really can’t ig...
# 2  Scopri come aumentare esposizione e visibilità...
#
#                                               og:url  \
# 0  https://wordlift.io/academy-entries/knowledge-...
# 1  https://wordlift.io/webinar-mobile-first-index...
# 2  https://wordlift.io/it/academy-entries/dati-st...
#
#                 og:site_name  \
# 0  AI-Powered SEO • WordLift
# 1  AI-Powered SEO • WordLift
# 2  AI-Powered SEO • WordLift
#
#                                             og:image  og:image:width  \
# 0  https://wordlift.io/wp-content/uploads/2020/04...           961.0
# 1  https://wordlift.io/wp-content/uploads/2020/03...          1280.0
# 2                                                NaN             NaN
#
#    og:image:height og:image:type         twitter:card     twitter:label1  \
# 0            540.0     image/png  summary_large_image  Est. reading time
# 1            720.0     image/png  summary_large_image  Est. reading time
# 2              NaN           NaN  summary_large_image  Est. reading time
#
#   twitter:data1     jsonld_@context  \
# 0     2 minutes  https://schema.org
# 1     2 minutes  https://schema.org
# 2      1 minute  https://schema.org
#
#                                        jsonld_@graph  jsonld_1_@context  \
# 0  [{'@type': 'WebPage', '@id': 'https://wordlift...  http://schema.org
# 1  [{'@type': 'WebPage', '@id': 'https://wordlift...  http://schema.org
# 2  [{'@type': 'WebPage', '@id': 'https://wordlift...  http://schema.org
#
#                                         jsonld_1_@id jsonld_1_@type  \
# 0  http://data.wordlift.io/wl01893/academy-entrie...         Course
# 1  http://data.wordlift.io/wl01893/academy-entrie...    VideoObject
# 2  http://data.wordlift.io/wl01893/academy-entrie...         Course
#
#                                 jsonld_1_description  \
# 0  [In the world of zero-click searches, the pote...
# 1  [If you are working in SEO, you really can’t i...
# 2  [Scopri con Marco Maltraversi come aumentare e...
#
#                            jsonld_1_mainEntityOfPage  \
# 0  https://wordlift.io/academy-entries/knowledge-...
# 1  https://wordlift.io/academy-entries/mobile-fir...
# 2  https://wordlift.io/academy-entries/dati-strut...
#
#                                       jsonld_1_image  \
# 0  [{'@type': 'ImageObject', 'url': 'https://eacn...
# 1  [{'@type': 'ImageObject', 'url': 'https://eacn...
# 2                                               None
#
#                                        jsonld_1_name  \
# 0  [Knowledge Graph and Panels | Webinar With And...
# 1  [Mobile First Indexing | Webinar with Cindy Kr...
# 2  [Come sfruttare i dati strutturati per aumenta...
#
#                                         jsonld_1_url  \
# 0  https://wordlift.io/academy-entries/knowledge-...
# 1  https://wordlift.io/academy-entries/mobile-fir...
# 2  https://wordlift.io/academy-entries/dati-strut...
#
#                                    jsonld_1_provider  \
# 0  [{'@id': 'http://data.wordlift.io/wl01893/enti...
# 1                                                NaN
# 2  [{'@id': 'http://data.wordlift.io/wl01893/enti...
#
#   jsonld_1_educationalLevel jsonld_1_inLanguage  \
# 0              intermediate                  En
# 1                       NaN                 NaN
# 2              intermediate                  It
#
#                                       jsonld_1_about  \
# 0  [{'@id': 'http://data.wordlift.io/wl01893/enti...
# 1  [{'@id': 'http://data.wordlift.io/wl01893/enti...
# 2                                                NaN
#
#                                    jsonld_1_mentions  \
# 0  [{'@id': 'http://data.wordlift.io/wl01893/enti...
# 1  [{'@id': 'http://data.wordlift.io/wl01893/enti...
# 2  [{'@id': 'http://data.wordlift.io/wl01893/enti...
#
#   jsonld_1_offers.availability  \
# 0                      InStock
# 1                          NaN
# 2                      InStock
#
#                                  jsonld_1_offers.url jsonld_1_offers.@type  \
# 0  https://wordlift.io/academy-entries/knowledge-...                 Offer
# 1                                                NaN                   NaN
# 2  https://wordlift.io/academy-entries/dati-strut...                 Offer
#
#   jsonld_1_sameAs jsonld_1_alternateName  jsonld_1_legalName  jsonld_1_email  \
# 0            None                   None                 NaN             NaN
# 1            None                    NaN                 NaN             NaN
# 2            None                    NaN                 NaN             NaN
#
#    jsonld_1_telephone  jsonld_1_address.@type  jsonld_1_address.streetAddress  \
# 0                 NaN                     NaN                             NaN
# 1                 NaN                     NaN                             NaN
# 2                 NaN                     NaN                             NaN
#
#    jsonld_1_address.postOfficeBoxNumber  jsonld_1_address.postalCode  \
# 0                                   NaN                          NaN
# 1                                   NaN                          NaN
# 2                                   NaN                          NaN
#
#    jsonld_1_address.addressLocality  jsonld_1_address.addressRegion  \
# 0                               NaN                             NaN
# 1                               NaN                             NaN
# 2                               NaN                             NaN
#
#    jsonld_1_address.addressCountry  \
# 0                              NaN
# 1                              NaN
# 2                              NaN
#
#                                            body_text    size  \
# 0  Solutions \n \n By Market \n \n SEO Management...  101567
# 1  Solutions \n \n By Market \n \n SEO Management...  101140
# 2  Solutions \n \n By Market \n \n SEO Management...   93751
#
#    download_timeout download_slot  download_latency  depth  status  \
# 0               180   wordlift.io          1.197423      0     200
# 1               180   wordlift.io          1.762641      0     200
# 2               180   wordlift.io          1.360074      0     200
#
#                                            links_url  \
# 0  https://wordlift.io/@@https://wordlift.io/acad...
# 1  https://wordlift.io/@@https://wordlift.io/acad...
# 2  https://wordlift.io/@@https://wordlift.io/acad...
#
#                                           links_text  \
# 0  \n\n@@Solutions@@By Market@@SEO Management Ser...
# 1  \n\n@@Solutions@@By Market@@SEO Management Ser...
# 2  \n\n@@Solutions@@By Market@@SEO Management Ser...
#
#                                       links_nofollow  \
# 0  False@@False@@False@@False@@False@@False@@Fals...
# 1  False@@False@@False@@False@@False@@False@@Fals...
# 2  False@@False@@False@@False@@False@@False@@Fals...
#
#                                        nav_links_url  \
# 0  https://wordlift.io/academy-entries/knowledge-...
# 1  https://wordlift.io/academy-entries/mobile-fir...
# 2  https://wordlift.io/academy-entries/dati-strut...
#
#                                       nav_links_text  \
# 0  Solutions@@By Market@@SEO Management ServiceSt...
# 1  Solutions@@By Market@@SEO Management ServiceSt...
# 2  Solutions@@By Market@@SEO Management ServiceSt...
#
#                                   nav_links_nofollow  \
# 0  False@@False@@False@@False@@False@@False@@Fals...
# 1  False@@False@@False@@False@@False@@False@@Fals...
# 2  False@@False@@False@@False@@False@@False@@Fals...
#
#                                     header_links_url  \
# 0  https://wordlift.io/@@https://wordlift.io/acad...
# 1  https://wordlift.io/@@https://wordlift.io/acad...
# 2  https://wordlift.io/@@https://wordlift.io/acad...
#
#                                    header_links_text  \
# 0  \n\n@@Solutions@@By Market@@SEO Management Ser...
# 1  \n\n@@Solutions@@By Market@@SEO Management Ser...
# 2  \n\n@@Solutions@@By Market@@SEO Management Ser...
#
#                                header_links_nofollow  \
# 0  False@@False@@False@@False@@False@@False@@Fals...
# 1  False@@False@@False@@False@@False@@False@@Fals...
# 2  False@@False@@False@@False@@False@@False@@Fals...
#
#                                     footer_links_url  \
# 0  https://wordlift.io/choose-your-plan/@@https:/...
# 1  https://wordlift.io/choose-your-plan/@@https:/...
# 2  https://wordlift.io/choose-your-plan/@@https:/...
#
#                                    footer_links_text  \
# 0  Try it for free@@Book A Demo@@Get a quote@@Boo...
# 1  Try it for free@@Book A Demo@@Get a quote@@Boo...
# 2  Try it for free@@Book A Demo@@Get a quote@@Boo...
#
#                                footer_links_nofollow  \
# 0  False@@False@@False@@False@@False@@False@@Fals...
# 1  False@@False@@False@@False@@False@@False@@Fals...
# 2  False@@False@@False@@False@@False@@False@@Fals...
#
#                                              img_src          img_width  \
# 0  https://eacn2n47zot.exactdn.com/wp-content/upl...  4010@@1080@@847@@
# 1  https://eacn2n47zot.exactdn.com/wp-content/upl...  4010@@1080@@300@@
# 2  https://eacn2n47zot.exactdn.com/wp-content/upl...             4010@@
#
#          img_height                                            img_alt  \
# 0  1241@@675@@303@@  AI-Powered SEO • WordLift@@Knowledge Graph and...
# 1  1241@@675@@300@@  AI-Powered SEO • WordLift@@Mobile First Indexi...
# 2            1241@@                        AI-Powered SEO • WordLift@@
#
#   img_fetchpriority img_decoding  \
# 0        @@@@high@@  @@@@async@@
# 1        @@@@high@@  @@@@async@@
# 2               NaN          NaN
#
#                                           img_srcset  \
# 0  @@@@https://eacn2n47zot.exactdn.com/wp-content...
# 1  @@@@https://eacn2n47zot.exactdn.com/wp-content...
# 2                                                NaN
#
#                                            img_sizes    ip_address  \
# 0  @@@@(min-width: 0px) and (max-width: 480px) 48...  104.18.8.209
# 1              @@@@(max-width: 300px) 100vw, 300px@@  104.18.8.209
# 2                                                NaN  104.18.8.209
#
#            crawl_time              resp_headers_Date  \
# 0 2024-03-15 19:04:59  Fri, 15 Mar 2024 19:04:59 GMT
# 1 2024-03-15 19:04:59  Fri, 15 Mar 2024 19:04:59 GMT
# 2 2024-03-15 19:04:59  Fri, 15 Mar 2024 19:04:59 GMT
#
#   resp_headers_Content-Type   resp_headers_Cf-Ray  \
# 0  text/html; charset=UTF-8  864ec5b4391132a8-AMM
# 1  text/html; charset=UTF-8  864ec5b43c6632ad-AMM
# 2  text/html; charset=UTF-8  864ec5b45eef32ab-AMM
#
#   resp_headers_Cf-Cache-Status resp_headers_Cache-Control  \
# 0                         MISS      public, max-age=14400
# 1                         MISS      public, max-age=14400
# 2                         MISS      public, max-age=14400
#
#             resp_headers_Expires     resp_headers_Last-Modified  \
# 0  Fri, 15 Mar 2024 23:04:59 GMT  Fri, 15 Mar 2024 19:04:59 GMT
# 1  Fri, 15 Mar 2024 23:04:59 GMT  Fri, 15 Mar 2024 19:04:59 GMT
# 2  Fri, 15 Mar 2024 23:04:59 GMT  Fri, 15 Mar 2024 19:04:59 GMT
#
#                                    resp_headers_Link  \
# 0  <https://wordlift.io/wp-json/>; rel="https://a...
# 1  <https://wordlift.io/wp-json/>; rel="https://a...
# 2  <https://wordlift.io/wp-json/>; rel="https://a...
#
#                              resp_headers_Set-Cookie resp_headers_Vary  \
# 0  sq51mybo=m76hppjgn86b; expires=Wed, 20-Mar-202...   Accept-Encoding
# 1  sq51mybo=m76hppjgn86b; expires=Wed, 20-Mar-202...   Accept-Encoding
# 2  sq51mybo=m76hppjgn86b; expires=Wed, 20-Mar-202...   Accept-Encoding
#
#   resp_headers_Cf-Apo-Via resp_headers_Cf-Edge-Cache  \
# 0             origin,miss   cache,platform=wordpress
# 1             origin,miss   cache,platform=wordpress
# 2             origin,miss   cache,platform=wordpress
#
#   resp_headers_Ki-Cache-Type resp_headers_Ki-Cf-Cache-Status  \
# 0                       None                          BYPASS
# 1                       None                          BYPASS
# 2                       None                          BYPASS
#
#   resp_headers_Ki-Edge resp_headers_Ki-Edge-O2O resp_headers_Ki-Origin  \
# 0    v=20.2.7;mv=3.0.4                      yes                    g1p
# 1    v=20.2.7;mv=3.0.4                      yes                    g1p
# 2    v=20.2.7;mv=3.0.4                      yes                    g1p
#
#                                     resp_headers_Nel  \
# 0  {"success_fraction":0.01,"report_to":"cf-nel",...
# 1  {"success_fraction":0.01,"report_to":"cf-nel",...
# 2  {"success_fraction":0.01,"report_to":"cf-nel",...
#
#                               resp_headers_Report-To  \
# 0  {"endpoints":[{"url":"https:\/\/a.nel.cloudfla...
# 1  {"endpoints":[{"url":"https:\/\/a.nel.cloudfla...
# 2  {"endpoints":[{"url":"https:\/\/a.nel.cloudfla...
#
#   resp_headers_X-Content-Type-Options  resp_headers_X-Edge-Location-Klb  \
# 0                             nosniff                                 1
# 1                             nosniff                                 1
# 2                             nosniff                                 1
#
#   resp_headers_X-Frame-Options resp_headers_X-Kinsta-Cache  \
# 0                   SAMEORIGIN                        MISS
# 1                   SAMEORIGIN                     EXPIRED
# 2                   SAMEORIGIN                        MISS
#
#   resp_headers_Server                             request_headers_Accept  \
# 0          cloudflare  text/html,application/xhtml+xml,application/xm...
# 1          cloudflare  text/html,application/xhtml+xml,application/xm...
# 2          cloudflare  text/html,application/xhtml+xml,application/xm...
#
#   request_headers_Accept-Language request_headers_User-Agent  \
# 0                              en          advertools/0.14.2
# 1                              en          advertools/0.14.2
# 2                              en          advertools/0.14.2
#
#   request_headers_Accept-Encoding  \
# 0               gzip, deflate, br
# 1               gzip, deflate, br
# 2               gzip, deflate, br
#
#                                                   h2  \
# 0                                                NaN
# 1  Why You Can’t Ignore Mobile First Indexing Any...
# 2  Perché dovrebbe interessarti?@@Cosa imparerai?...
#
#                                jsonld_1_thumbnailUrl jsonld_1_uploadDate  \
# 0                                                NaN                 NaN
# 1  https://wordlift.io/wp-content/uploads/2020/03...          2019/05/21
# 2                                                NaN                 NaN
#
#                                 jsonld_1_contentUrl jsonld_1_duration  \
# 0                                               NaN               NaN
# 1  https://cdn.jwplayer.com/manifests/Zx2gEWsn.m3u8          PT57M45S
# 2                                               NaN               NaN
#
#                                   jsonld_1_embedUrl jsonld_1_expires  \
# 0                                               NaN              NaN
# 1  https://cdn.jwplayer.com/manifests/Zx2gEWsn.m3u8       2021/12/31
# 2                                               NaN              NaN
#
#                                     jsonld_1_hasPart  jsonld_1_mentions.@id  \
# 0                                                NaN                    NaN
# 1  [{'endOffset': '742', 'startOffset': '397', 'u...                    NaN
# 2                                                NaN                    NaN
#
#   jsonld_1_headline jsonld_1_datePublished jsonld_1_dateModified  \
# 0               NaN                    NaN                   NaN
# 1               NaN                    NaN                   NaN
# 2               NaN                    NaN                   NaN
#
#    jsonld_1_wordCount  jsonld_1_commentCount jsonld_1_publisher.@type  \
# 0                 NaN                    NaN                      NaN
# 1                 NaN                    NaN                      NaN
# 2                 NaN                    NaN                      NaN
#
#   jsonld_1_publisher.@id jsonld_1_publisher.name jsonld_1_publisher.sameAs  \
# 0                    NaN                     NaN                       NaN
# 1                    NaN                     NaN                       NaN
# 2                    NaN                     NaN                       NaN
#
#   jsonld_1_publisher.logo.@type jsonld_1_publisher.logo.url  \
# 0                           NaN                         NaN
# 1                           NaN                         NaN
# 2                           NaN                         NaN
#
#    jsonld_1_publisher.logo.width  jsonld_1_publisher.logo.height  \
# 0                            NaN                             NaN
# 1                            NaN                             NaN
# 2                            NaN                             NaN
#
#   jsonld_1_author.@type jsonld_1_author.@id jsonld_1_author.name  \
# 0                   NaN                 NaN                  NaN
# 1                   NaN                 NaN                  NaN
# 2                   NaN                 NaN                  NaN
#
#   jsonld_1_author.givenName jsonld_1_author.familyName jsonld_1_author.url  \
# 0                       NaN                        NaN                 NaN
# 1                       NaN                        NaN                 NaN
# 2                       NaN                        NaN                 NaN
#
#   jsonld_1_publication.endDate jsonld_1_publication.startDate  \
# 0                          NaN                            NaN
# 1                          NaN                            NaN
# 2                          NaN                            NaN
#
#   jsonld_1_publication.name jsonld_1_publication.@type  redirect_times  \
# 0                       NaN                        NaN             NaN
# 1                       NaN                        NaN             NaN
# 2                       NaN                        NaN             NaN
#
#    redirect_ttl redirect_urls  redirect_reasons request_headers_Cookie  \
# 0           NaN           NaN               NaN                    NaN
# 1           NaN           NaN               NaN                    NaN
# 2           NaN           NaN               NaN                    NaN
#
#    jsonld_1_itemListElement jsonld_1_coursePrerequisites  \
# 0                       NaN                          NaN
# 1                       NaN                          NaN
# 2                       NaN                          NaN
#
#   jsonld_1_competencyRequired twitter:title twitter:description twitter:image  \
# 0                         NaN           NaN                 NaN           NaN
# 1                         NaN           NaN                 NaN           NaN
# 2                         NaN           NaN                 NaN           NaN
#
#   jsonld_1_mainEntity  jsonld_1_publication.isLiveBroadcast jsonld_1_teaches  \
# 0                 NaN                                   NaN              NaN
# 1                 NaN                                   NaN              NaN
# 2                 NaN                                   NaN              NaN
#
#   jsonld_1_affiliation.@id alt_hreflang twitter:label2 twitter:data2  \
# 0                      NaN          NaN            NaN           NaN
# 1                      NaN          NaN            NaN           NaN
# 2                      NaN          NaN            NaN           NaN
#
#   jsonld_1_articleSection jsonld_1_video jsonld_1_author jsonld_1_about.@id  \
# 0                     NaN            NaN             NaN                NaN
# 1                     NaN            NaN             NaN                NaN
# 2                     NaN            NaN             NaN                NaN
#
#    jsonld_1_knows  jsonld_1_birthDate  jsonld_1_birthPlace.@id  \
# 0             NaN                 NaN                      NaN
# 1             NaN                 NaN                      NaN
# 2             NaN                 NaN                      NaN
#
#    jsonld_1_interactionStatistic.@type  \
# 0                                  NaN
# 1                                  NaN
# 2                                  NaN
#
#    jsonld_1_interactionStatistic.interactionType.@type  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
#
#    jsonld_1_interactionStatistic.userInteractionCount  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
#
#   jsonld_1_potentialAction.@type jsonld_1_potentialAction.target  \
# 0                            NaN                             NaN
# 1                            NaN                             NaN
# 2                            NaN                             NaN
#
#   jsonld_1_potentialAction.query-input  resp_headers_Age   h6   h5  \
# 0                                  NaN               NaN  NaN  NaN
# 1                                  NaN               NaN  NaN  NaN
# 2                                  NaN               NaN  NaN  NaN
#
#   jsonld_1_isRelatedTo jsonld_1_isSimilarTo jsonld_1_areaServed  \
# 0                  NaN                  NaN                 NaN
# 1                  NaN                  NaN                 NaN
# 2                  NaN                  NaN                 NaN
#
#   jsonld_1_provider.@id jsonld_1_title jsonld_1_datePosted  \
# 0                   NaN            NaN                 NaN
# 1                   NaN            NaN                 NaN
# 2                   NaN            NaN                 NaN
#
#   jsonld_1_hiringOrganization jsonld_1_jobLocation jsonld_1_employmentType  \
# 0                         NaN                  NaN                     NaN
# 1                         NaN                  NaN                     NaN
# 2                         NaN                  NaN                     NaN
#
#   jsonld_1_validThrough jsonld_1_experienceRequirements  \
# 0                   NaN                             NaN
# 1                   NaN                             NaN
# 2                   NaN                             NaN
#
#   jsonld_1_responsibilities jsonld_1_employerOverview jsonld_1_industry  \
# 0                       NaN                       NaN               NaN
# 1                       NaN                       NaN               NaN
# 2                       NaN                       NaN               NaN
#
#   jsonld_1_baseSalary.currency jsonld_1_baseSalary.@type  \
# 0                          NaN                       NaN
# 1                          NaN                       NaN
# 2                          NaN                       NaN
#
#   jsonld_1_baseSalary.value.@type jsonld_1_baseSalary.value.unitText  \
# 0                             NaN                                NaN
# 1                             NaN                                NaN
# 2                             NaN                                NaN
#
#   jsonld_1_educationRequirements jsonld_1_audience jsonld_1_category  \
# 0                            NaN               NaN               NaN
# 1                            NaN               NaN               NaN
# 2                            NaN               NaN               NaN
#
#   jsonld_1_serviceType jsonld_1_serviceOutput
# 0                  NaN                    NaN
# 1                  NaN                    NaN
# 2                  NaN                    NaN

# %% [markdown]
# ## Extracting attributes of `WebPage`
#
# * Rename some columns to comply with the spec, e.g. `title` ==> `metaTitleContent`
# * Run some checks and create new columns showing the result of the checks, e.g. `containsmage` checks if the `img_src` is not empty.
#
# The following elements are extracted:
#
# * `containsImage`
# * `containsVideo`
# * `hasMetaDescription`
# * `hasMetaTitle`
# * `usesSchema`
# * `Internal_Links`
#     * `anchorTextContent`
#     * `NoFollow`
#     * `Link`

# %%
crawl_df = crawl_df.rename(columns={
    'title': 'metaTitleContent',
    'meta_desc': 'metaDescriptionContent'
})
crawl_df['hasMetaTitle'] = crawl_df['metaTitleContent'].notna()
crawl_df['hasMetaDescription'] = crawl_df['metaDescriptionContent'].notna()
crawl_df['containsImage'] = crawl_df['img_src'].notna()
crawl_df['usesSchema'] = crawl_df.filter(regex='jsonld').notna().sum(axis=1).gt(0)

# %% [markdown]
# ## Summarize internal links on the website

# %%
link_df = adv.crawlytics.links(crawl_df, internal_url_regex=r'^https://wordlift\.io')
link_df.groupby('url').head(3).head(9)
# Out:
#                                                  url  \
# 0  https://wordlift.io/academy-entries/knowledge-...
# 0  https://wordlift.io/academy-entries/knowledge-...
# 0  https://wordlift.io/academy-entries/knowledge-...
# 1  https://wordlift.io/academy-entries/mobile-fir...
# 1  https://wordlift.io/academy-entries/mobile-fir...
# 1  https://wordlift.io/academy-entries/mobile-fir...
# 2  https://wordlift.io/academy-entries/dati-strut...
# 2  https://wordlift.io/academy-entries/dati-strut...
# 2  https://wordlift.io/academy-entries/dati-strut...
#
#                                                 link       text nofollow  \
# 0                               https://wordlift.io/       \n\n    False
# 0  https://wordlift.io/academy-entries/knowledge-...  Solutions    False
# 0  https://wordlift.io/academy-entries/knowledge-...  By Market    False
# 1                               https://wordlift.io/       \n\n    False
# 1  https://wordlift.io/academy-entries/mobile-fir...  Solutions    False
# 1  https://wordlift.io/academy-entries/mobile-fir...  By Market    False
# 2                               https://wordlift.io/       \n\n    False
# 2  https://wordlift.io/academy-entries/dati-strut...  Solutions    False
# 2  https://wordlift.io/academy-entries/dati-strut...  By Market    False
#
#    internal
# 0      True
# 0      True
# 0      True
# 1      True
# 1      True
# 1      True
# 2      True
# 2      True
# 2      True

# %%
for url in crawl_df['url']:
    internal_links = link_df[link_df['internal'] & link_df['link'].eq(url)]
    Internal_Links_url = internal_links['url'].str.cat(sep='@@')
    Internal_Links_text = internal_links['text'].str.cat(sep='@@')
    Internal_Links_nofollow = internal_links['nofollow'].astype(str).str.cat(sep='@@')
    crawl_df['Internal_Links_url'] = Internal_Links_url
    crawl_df['Internal_Links_text'] = Internal_Links_text
    crawl_df['Internal_Links_nofollow'] = Internal_Links_nofollow

# %% [markdown]
# ## Sample of converted columns and extracted data

# %%
crawl_df.filter(regex='^has|^contains|^url$|meta|^uses|Internal').head()
# Out:
#                                                  url  \
# 0  https://wordlift.io/academy-entries/knowledge-...
# 1  https://wordlift.io/academy-entries/mobile-fir...
# 2  https://wordlift.io/academy-entries/dati-strut...
# 3  https://wordlift.io/academy-entries/open-sourc...
# 4  https://wordlift.io/academy-entries/voice-sear...
#
#                                     metaTitleContent  \
# 0  Knowledge Graph and Panels | Webinar With Andr...
# 1    Mobile First Indexing | Webinar with Cindy Krum
# 2  Come sfruttare i dati strutturati per aumentar...
# 3  Open Source Knowledge Graph: Build Your Own be...
# 4  Is Voice Here to Stay? It is now 2020 — Live W...
#
#                               metaDescriptionContent  hasMetaTitle  \
# 0  Join the webinar to learn all the relevant tip...          True
# 1  If you are working in SEO, you really can’t ig...          True
# 2  Scopri come aumentare esposizione e visibilità...          True
# 3  Take a step forward and start creating your ow...          True
# 4  Learn from this webinar tips about voice searc...          True
#
#    hasMetaDescription  containsImage  usesSchema  \
# 0                True           True        True
# 1                True           True        True
# 2                True           True        True
# 3                True           True        True
# 4                True           True        True
#
#                                   Internal_Links_url  \
# 0  https://wordlift.io/case-studies/news-and-medi...
# 1  https://wordlift.io/case-studies/news-and-medi...
# 2  https://wordlift.io/case-studies/news-and-medi...
# 3  https://wordlift.io/case-studies/news-and-medi...
# 4  https://wordlift.io/case-studies/news-and-medi...
#
#                                  Internal_Links_text  \
# 0  Solutions@@By Market@@By Plan@@Product@@Our Pr...
# 1  Solutions@@By Market@@By Plan@@Product@@Our Pr...
# 2  Solutions@@By Market@@By Plan@@Product@@Our Pr...
# 3  Solutions@@By Market@@By Plan@@Product@@Our Pr...
# 4  Solutions@@By Market@@By Plan@@Product@@Our Pr...
#
#                              Internal_Links_nofollow
# 0  False@@False@@False@@False@@False@@False@@Fals...
# 1  False@@False@@False@@False@@False@@False@@Fals...
# 2  False@@False@@False@@False@@False@@False@@Fals...
# 3  False@@False@@False@@False@@False@@False@@Fals...
# 4  False@@False@@False@@False@@False@@False@@Fals...

# %%
import random
crawl_df['gsc_7DaysClicks'] = [random.randint(10, 200) for i in range(len(crawl_df))]
crawl_df['gsc_7DaysImpressions'] = [random.randint(1000, 10000) for i in range(len(crawl_df))]

# %% [markdown]
# ## Convert to JSON
#
# Example of [https://wordlift.io/academy-entries/knowledge-graph-and-panels-webinar/](https://wordlift.io/academy-entries/knowledge-graph-and-panels-webinar/)

# %%
from pprint import pprint
# pprint(crawl_df.filter(regex='^has|^contains|^url$|meta|Internal').head(1).to_dict(orient='records')[0], indent=4)

# %% [markdown]
# ```json
#
# {   'Internal_Links_nofollow': 'False@@False@@False@@False@@False@@False@@False@@False',
#     'Internal_Links_text': 'Solutions@@By Market@@By Plan@@Product@@Our '
#                            'Products@@Smart ContentImprove your search '
#                            'visibility with AI-Driven '
#                            'Solutions.@@Resources@@Learn',
#     'Internal_Links_url': 'https://wordlift.io/case-studies/news-and-media/@@https://wordlift.io/case-studies/news-and-media/@@https://wordlift.io/case-studies/news-and-media/@@https://wordlift.io/case-studies/news-and-media/@@https://wordlift.io/case-studies/news-and-media/@@https://wordlift.io/case-studies/news-and-media/@@https://wordlift.io/case-studies/news-and-media/@@https://wordlift.io/case-studies/news-and-media/',
#     'containsImage': True,
#     'hasMetaDescription': True,
#     'hasMetaTitle': True,
#     'metaDescriptionContent': 'Join the webinar to learn all the relevant tips '
#                               'to improve your branding on Google’s Knowledge '
#                               'Graph panels.',
#     'metaTitleContent': 'Knowledge Graph and Panels | Webinar With Andrea '
#                         'Volpini, Jason Barnard and Dixon Jones - AI-Powered '
#                         'SEO • WordLift',
#     'url': 'https://wordlift.io/academy-entries/knowledge-graph-and-panels-webinar/'}
# ```

# %% [markdown]
# Example of [https://wordlift.io/academy-entries/mobile-first-indexing](https://wordlift.io/academy-entries/mobile-first-indexing)

# %%
# pprint(crawl_df.filter(regex='^has|^contains|^url$|meta|Internal').head(2).to_dict(orient='records')[1], indent=4)

# %% [markdown]
# ```json
# {   'Internal_Links_nofollow': 'False@@False@@False@@False@@False@@False@@False@@False',
#     'Internal_Links_text': 'Solutions@@By Market@@By Plan@@Product@@Our '
#                            'Products@@Smart ContentImprove your search '
#                            'visibility with AI-Driven '
#                            'Solutions.@@Resources@@Learn',
#     'Internal_Links_url': 'https://wordlift.io/case-studies/news-and-media/@@https://wordlift.io/case-studies/news-and-media/@@https://wordlift.io/case-studies/news-and-media/@@https://wordlift.io/case-studies/news-and-media/@@https://wordlift.io/case-studies/news-and-media/@@https://wordlift.io/case-studies/news-and-media/@@https://wordlift.io/case-studies/news-and-media/@@https://wordlift.io/case-studies/news-and-media/',
#     'containsImage': True,
#     'hasMetaDescription': True,
#     'hasMetaTitle': True,
#     'metaDescriptionContent': 'If you are working in SEO, you really can’t '
#                               'ignore how the Mobile First Indexing is '
#                               'rearranging Google’s index. Watch Cindy Krum’s '
#                               'webinar!',
#     'metaTitleContent': 'Mobile First Indexing | Webinar with Cindy Krum',
#     'url': 'https://wordlift.io/academy-entries/mobile-first-indexing/'}
# ```

# %% [markdown]
# ## Extracted elements' usage

# %%
(crawl_df
 .filter(regex='^has|^contains|^url$|^uses')
 .notna()
 .mean()
 .to_frame()[1:]
 .rename(columns={0: '% usage'})
 .style
 .format('{:.1%}'))
# Out:
# <style type="text/css">
# </style>
# <table id="T_425af">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_425af_level0_col0" class="col_heading level0 col0" >% usage</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_425af_level0_row0" class="row_heading level0 row0" >hasMetaTitle</th>
#       <td id="T_425af_row0_col0" class="data row0 col0" >100.0%</td>
#     </tr>
#     <tr>
#       <th id="T_425af_level0_row1" class="row_heading level0 row1" >hasMetaDescription</th>
#       <td id="T_425af_row1_col0" class="data row1 col0" >100.0%</td>
#     </tr>
#     <tr>
#       <th id="T_425af_level0_row2" class="row_heading level0 row2" >containsImage</th>
#       <td id="T_425af_row2_col0" class="data row2 col0" >100.0%</td>
#     </tr>
#     <tr>
#       <th id="T_425af_level0_row3" class="row_heading level0 row3" >usesSchema</th>
#       <td id="T_425af_row3_col0" class="data row3 col0" >100.0%</td>
#     </tr>
#   </tbody>
# </table>
